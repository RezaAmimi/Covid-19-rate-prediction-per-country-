# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv("data_filteredfor asia.csv")
df
# Out:
#         dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0      12/14/20   14     12  2020    746       6             Afghanistan
# 1      12/13/20   13     12  2020    298       9             Afghanistan
# 2      12/12/20   12     12  2020    113      11             Afghanistan
# 3      11/12/20   11     12  2020     63      10             Afghanistan
# 4      10/12/20   10     12  2020    202      16             Afghanistan
# ...         ...  ...    ...   ...    ...     ...                     ...
# 61895   3/25/20   25      3  2020      0       0                Zimbabwe
# 61896   3/24/20   24      3  2020      0       1                Zimbabwe
# 61897   3/23/20   23      3  2020      0       0                Zimbabwe
# 61898   3/22/20   22      3  2020      1       0                Zimbabwe
# 61899   3/21/20   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# 0        AF                  AFG   38041757.0         Asia
# 1        AF                  AFG   38041757.0         Asia
# 2        AF                  AFG   38041757.0         Asia
# 3        AF                  AFG   38041757.0         Asia
# 4        AF                  AFG   38041757.0         Asia
# ...     ...                  ...          ...          ...
# 61895    ZW                  ZWE   14645473.0       Africa
# 61896    ZW                  ZWE   14645473.0       Africa
# 61897    ZW                  ZWE   14645473.0       Africa
# 61898    ZW                  ZWE   14645473.0       Africa
# 61899    ZW                  ZWE   14645473.0       Africa
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                               9.013779
# 1                                               7.052776
# 2                                               6.868768
# 3                                               7.134266
# 4                                               6.968658
# ...                                                  ...
# 61895                                                NaN
# 61896                                                NaN
# 61897                                                NaN
# 61898                                                NaN
# 61899                                                NaN
#
# [61900 rows x 12 columns]

# %%
df1 = df.drop(['day','month','year','countryterritoryCode'],axis=1)
df1
# Out:
#         dateRep  cases  deaths countriesAndTerritories geoId  popData2019  \
# 0      12/14/20    746       6             Afghanistan    AF   38041757.0
# 1      12/13/20    298       9             Afghanistan    AF   38041757.0
# 2      12/12/20    113      11             Afghanistan    AF   38041757.0
# 3      11/12/20     63      10             Afghanistan    AF   38041757.0
# 4      10/12/20    202      16             Afghanistan    AF   38041757.0
# ...         ...    ...     ...                     ...   ...          ...
# 61895   3/25/20      0       0                Zimbabwe    ZW   14645473.0
# 61896   3/24/20      0       1                Zimbabwe    ZW   14645473.0
# 61897   3/23/20      0       0                Zimbabwe    ZW   14645473.0
# 61898   3/22/20      1       0                Zimbabwe    ZW   14645473.0
# 61899   3/21/20      1       0                Zimbabwe    ZW   14645473.0
#
#       continentExp  Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0             Asia                                           9.013779
# 1             Asia                                           7.052776
# 2             Asia                                           6.868768
# 3             Asia                                           7.134266
# 4             Asia                                           6.968658
# ...            ...                                                ...
# 61895       Africa                                                NaN
# 61896       Africa                                                NaN
# 61897       Africa                                                NaN
# 61898       Africa                                                NaN
# 61899       Africa                                                NaN
#
# [61900 rows x 8 columns]

# %%
df2 = df1.sort_values(by ='continentExp', ascending = 1)
df2
# Out:
#         dateRep  cases  deaths                     countriesAndTerritories  \
# 30949  10/24/20    631      14                                       Kenya
# 24963   5/17/20      0       0                               Guinea_Bissau
# 24962   5/18/20     77       1                               Guinea_Bissau
# 24961   5/19/20      0       0                               Guinea_Bissau
# 24960   5/20/20     48       2                               Guinea_Bissau
# ...         ...    ...     ...                                         ...
# 10979   1/19/20      0       0  Cases_on_an_international_conveyance_Japan
# 10978   1/20/20      0       0  Cases_on_an_international_conveyance_Japan
# 10977   1/21/20      0       0  Cases_on_an_international_conveyance_Japan
# 10987   1/11/20      0       0  Cases_on_an_international_conveyance_Japan
# 10973   1/25/20      0       0  Cases_on_an_international_conveyance_Japan
#
#           geoId  popData2019 continentExp  \
# 30949        KE   52573967.0       Africa
# 24963        GW    1920917.0       Africa
# 24962        GW    1920917.0       Africa
# 24961        GW    1920917.0       Africa
# 24960        GW    1920917.0       Africa
# ...         ...          ...          ...
# 10979  JPG11668          NaN        Other
# 10978  JPG11668          NaN        Other
# 10977  JPG11668          NaN        Other
# 10987  JPG11668          NaN        Other
# 10973  JPG11668          NaN        Other
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 30949                                          13.738739
# 24963                                          34.150356
# 24962                                          36.336812
# 24961                                          30.037737
# 24960                                          29.308919
# ...                                                  ...
# 10979                                                NaN
# 10978                                                NaN
# 10977                                                NaN
# 10987                                                NaN
# 10973                                                NaN
#
# [61900 rows x 8 columns]

# %%
df3 = df2[(df2.continentExp != 'Africa') & (df2.continentExp != 'Europe') & (df2.continentExp != 'America') & (df2.continentExp != 'Other') & (df2.continentExp != 'Oceania')]
df3
# Out:
#         dateRep  cases  deaths countriesAndTerritories geoId  popData2019  \
# 55933   9/19/20      0       0             Timor_Leste    TL    1293120.0
# 55929   9/23/20      0       0             Timor_Leste    TL    1293120.0
# 55930   9/22/20      0       0             Timor_Leste    TL    1293120.0
# 55931   9/21/20      0       0             Timor_Leste    TL    1293120.0
# 55932   9/20/20      0       0             Timor_Leste    TL    1293120.0
# ...         ...    ...     ...                     ...   ...          ...
# 35213   12/3/20    851       2                Malaysia    MY   31949789.0
# 35212   12/4/20   1075      11                Malaysia    MY   31949789.0
# 35211   12/5/20   1141       0                Malaysia    MY   31949789.0
# 35217  11/29/20   1315       0                Malaysia    MY   31949789.0
# 35564   12/1/20     17       0                Maldives    MV     530957.0
#
#       continentExp  Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 55933         Asia                                           0.000000
# 55929         Asia                                           0.000000
# 55930         Asia                                           0.000000
# 55931         Asia                                           0.000000
# 55932         Asia                                           0.000000
# ...            ...                                                ...
# 35213         Asia                                          55.180333
# 35212         Asia                                          54.507402
# 35211         Asia                                          55.080176
# 35217         Asia                                          53.105202
# 35564         Asia                                         131.272401
#
# [13241 rows x 8 columns]

# %%
df4 = df3[(df3.countriesAndTerritories != 'Timor_Leste') & (df3.countriesAndTerritories != 'Nepal')]
df4
# Out:
#         dateRep  cases  deaths countriesAndTerritories geoId  popData2019  \
# 60510   11/7/20      6       0                 Vietnam    VN   96462108.0
# 60511   11/6/20      0       0                 Vietnam    VN   96462108.0
# 60512   11/5/20      4       0                 Vietnam    VN   96462108.0
# 60513   11/4/20     11       0                 Vietnam    VN   96462108.0
# 60514   11/3/20     12       0                 Vietnam    VN   96462108.0
# ...         ...    ...     ...                     ...   ...          ...
# 35213   12/3/20    851       2                Malaysia    MY   31949789.0
# 35212   12/4/20   1075      11                Malaysia    MY   31949789.0
# 35211   12/5/20   1141       0                Malaysia    MY   31949789.0
# 35217  11/29/20   1315       0                Malaysia    MY   31949789.0
# 35564   12/1/20     17       0                Maldives    MV     530957.0
#
#       continentExp  Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 60510         Asia                                           0.067384
# 60511         Asia                                           0.061164
# 60512         Asia                                           0.064274
# 60513         Asia                                           0.064274
# 60514         Asia                                           0.053907
# ...            ...                                                ...
# 35213         Asia                                          55.180333
# 35212         Asia                                          54.507402
# 35211         Asia                                          55.080176
# 35217         Asia                                          53.105202
# 35564         Asia                                         131.272401
#
# [12636 rows x 8 columns]

# %%
# Shows each country and its average number of cases
df4 = df3.groupby('countriesAndTerritories',as_index=False)['Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'].mean()
# In[18]:
df4
# Out:
#    countriesAndTerritories  \
# 0              Afghanistan
# 1                  Bahrain
# 2               Bangladesh
# 3                   Bhutan
# 4        Brunei_Darussalam
# 5                 Cambodia
# 6                    China
# 7                    India
# 8                Indonesia
# 9                     Iran
# 10                    Iraq
# 11                  Israel
# 12                   Japan
# 13                  Jordan
# 14              Kazakhstan
# 15                  Kuwait
# 16              Kyrgyzstan
# 17                    Laos
# 18                 Lebanon
# 19                Malaysia
# 20                Maldives
# 21                Mongolia
# 22                 Myanmar
# 23                   Nepal
# 24                    Oman
# 25                Pakistan
# 26               Palestine
# 27             Philippines
# 28                   Qatar
# 29            Saudi_Arabia
# 30               Singapore
# 31             South_Korea
# 32               Sri_Lanka
# 33                   Syria
# 34                  Taiwan
# 35              Tajikistan
# 36                Thailand
# 37             Timor_Leste
# 38    United_Arab_Emirates
# 39              Uzbekistan
# 40                 Vietnam
# 41                   Yemen
#
#     Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                            5.352608
# 1                                          223.512419
# 2                                           15.683716
# 3                                            2.969699
# 4                                            1.260664
# 5                                            0.089633
# 6                                            0.266205
# 7                                           29.528471
# 8                                            9.063563
# 9                                           52.210230
# 10                                          60.038124
# 11                                         170.661438
# 12                                           5.352043
# 13                                         126.728895
# 14                                          51.973037
# 15                                         143.980376
# 16                                          63.828108
# 17                                           0.025737
# 18                                          84.213499
# 19                                           9.638114
# 20                                         130.279917
# 21                                           1.432223
# 22                                          10.172007
# 23                                          36.449989
# 24                                         106.198959
# 25                                           8.200112
# 26                                         117.978211
# 27                                          17.129848
# 28                                         207.793797
# 29                                          54.074293
# 30                                          41.703961
# 31                                           3.136947
# 32                                           5.670096
# 33                                           2.734942
# 34                                           0.124329
# 35                                           8.465535
# 36                                           0.250557
# 37                                           0.127068
# 38                                          76.629598
# 39                                          12.040632
# 40                                           0.059775
# 41                                           0.422698

# %%
# Shows each country and its average deaths
df5 = df3.groupby('countriesAndTerritories',as_index=False)['deaths'].mean()
# In[18]:
df5
# Out:
#    countriesAndTerritories      deaths
# 0              Afghanistan    5.797059
# 1                  Bahrain    0.997135
# 2               Bangladesh   25.643636
# 3                   Bhutan    0.000000
# 4        Brunei_Darussalam    0.010753
# 5                 Cambodia    0.000000
# 6                    China   13.540000
# 7                    India  410.759312
# 8                Indonesia   54.865889
# 9                     Iran  149.131429
# 10                    Iraq   36.146552
# 11                  Israel    8.642651
# 12                   Japan    7.385714
# 13                  Jordan   12.148014
# 14              Kazakhstan    9.280000
# 15                  Kuwait    2.625360
# 16              Kyrgyzstan    4.841328
# 17                    Laos    0.000000
# 18                 Lebanon    3.468208
# 19                Malaysia    1.189112
# 20                Maldives    0.171429
# 21                Mongolia    0.000000
# 22                 Myanmar    8.494382
# 23                   Nepal    5.038576
# 24                    Oman    4.276163
# 25                Pakistan   25.600000
# 26               Palestine    3.839858
# 27             Philippines   25.239884
# 28                   Qatar    0.693642
# 29            Saudi_Arabia   21.295775
# 30               Singapore    0.082857
# 31             South_Korea    1.677143
# 32               Sri_Lanka    0.445748
# 33                   Syria    1.940075
# 34                  Taiwan    0.020000
# 35              Tajikistan    0.385965
# 36                Thailand    0.174927
# 37             Timor_Leste    0.000000
# 38    United_Arab_Emirates    1.793605
# 39              Uzbekistan    2.233577
# 40                 Vietnam    0.101156
# 41                   Yemen    2.433735

# %%
# This shows the line graph for the number of cases in each asian country
plt.rcParams["figure.figsize"] = (20,3)
df4.plot.line(x="countriesAndTerritories",y="Cumulative_number_for_14_days_of_COVID-19_cases_per_100000")
plt.xticks(range(len(df4.countriesAndTerritories)), np.array(df4.countriesAndTerritories), rotation = 90);
# This picture didnt make sense to me before but you should look at as the five countries are just five that were chosen 
# and all of the other countries are in between them.

# %%
#Thiss shows the number of deaths for each asian country. This might be good to present on since some countries
# have way more deaths than other countries.
plt.rcParams["figure.figsize"] = (20,3)
df5.plot.line(x="countriesAndTerritories",y="deaths")
plt.xticks(range(len(df4.countriesAndTerritories)), np.array(df4.countriesAndTerritories), rotation = 90);

# %%
conda install -c conda-forge/label/cf201901 folium
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: /

# %%
# import the library
import folium

# Make an empty map
m = folium.Map(location=[20,0], tiles="OpenStreetMap", zoom_start=2)

# Show the map
m
